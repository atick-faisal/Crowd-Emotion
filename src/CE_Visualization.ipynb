# %% [markdown]
# <a href="https://colab.research.google.com/github/atick-faisal/Crowd-Emotion/blob/main/src/CE_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pathlib
from PIL import Image

# %%
data_dir = '/content/drive/MyDrive/Research/Crowd Emotion/Spectrograms/'
data_dir = pathlib.Path(data_dir)

# %%
approvals_mel = list(data_dir.glob('Mel/Approval/*'))
Image.open(str(approvals_mel[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56BF49160>

# %%
approvals_log = list(data_dir.glob('Log/Approval/*'))
Image.open(str(approvals_log[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56C002C88>

# %%
approvals_erb = list(data_dir.glob('Erb/Approval/*'))
Image.open(str(approvals_erb[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56A4B2080>

# %%
approvals_bark = list(data_dir.glob('Bark/Approval/*'))
Image.open(str(approvals_bark[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56A4B21D0>

# %%
disapprovals_mel = list(data_dir.glob('Mel/Disapproval/*'))
Image.open(str(disapprovals_mel[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56A4B2320>

# %%
disapprovals_log = list(data_dir.glob('Log/Disapproval/*'))
Image.open(str(disapprovals_log[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56A4B2438>

# %%
disapprovals_erb = list(data_dir.glob('Erb/Disapproval/*'))
Image.open(str(disapprovals_erb[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56A4B2550>

# %%
disapprovals_bark = list(data_dir.glob('Bark/Disapproval/*'))
Image.open(str(disapprovals_bark[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56A4B2828>

# %%
neutral_mel = list(data_dir.glob('Mel/Neutral/*'))
Image.open(str(neutral_mel[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56A4B2978>

# %%
neutral_log = list(data_dir.glob('Log/Neutral/*'))
Image.open(str(neutral_log[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56A4B2B38>

# %%
neutral_erb = list(data_dir.glob('Erb/Neutral/*'))
Image.open(str(neutral_erb[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56A4B2C50>

# %%
neutral_bark = list(data_dir.glob('Bark/Neutral/*'))
Image.open(str(neutral_bark[30]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=288x288 at 0x7FE56A4B2D68>
